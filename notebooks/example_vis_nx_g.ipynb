# %% [markdown]
# # Example Visualisation Module Usage

# %%
from ariadne.pipelines.vis_nx_g import return_fig_multigraph
from ariadne.nodes.utils_nx_g import generate_random_multidigraph

# %%
nx_g = generate_random_multidigraph(
    num_nodes=500, num_edges=1000, node_types=["ntype1", "ntype2"], edge_types=["etype1", "etyp2"]
)

fig = return_fig_multigraph(nx_g=nx_g)
fig
# Out:
# <div>                            <div id="efdeda8f-a0fd-4df8-9d69-9b25bd47ab6b" class="plotly-graph-div" style="height:960px; width:1280px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efdeda8f-a0fd-4df8-9d69-9b25bd47ab6b")) {                    Plotly.newPlot(                        "efdeda8f-a0fd-4df8-9d69-9b25bd47ab6b",                        [{"hoverinfo":"text","hovertext":["ntype: ntype1","ntype: ntype1","ntype: ntype1","ntype: ntype1","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype1","ntype: ntype1","ntype: ntype2","ntype: ntype1","ntype: ntype2","ntype: ntype1","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype1","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype2","ntype: ntype1","ntype: ntype1",
# ...
